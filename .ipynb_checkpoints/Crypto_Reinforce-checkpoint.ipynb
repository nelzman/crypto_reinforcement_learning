# %% [markdown]
# # Reinforcement Learning with Cryptodata

# %%
import os
import numpy as np
import pandas as pd
import pickle
import quandl
from datetime import datetime, timedelta, date
import plotly.offline as py
import plotly.graph_objs as go
import plotly.figure_factory as ff
import matplotlib.pyplot as plt

py.init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## load Data

# %%
data_full = pd.read_csv('data_full.csv')
#data_full['Date'] = pd.to_datetime(data_full['Date'])
data_full['Date'] = [pd.to_datetime(str(x) + ' 00:00:00',format = '%Y-%m-%d %H:%M:%S') for x in data_full['Date']] 
for x in data_full['Date'][:10]:
    print(str(x))
data_full = data_full.set_index('Date')
data_full.index = pd.to_datetime(data_full.index,format = '%Y-%m-%d %H:%M:%S')
data_full.index[:10]
# Out:
# 2016-07-25 00:00:00
# 2016-07-26 00:00:00
# 2016-07-27 00:00:00
# 2016-07-28 00:00:00
# 2016-07-29 00:00:00
# 2016-07-30 00:00:00
# 2016-07-31 00:00:00
# 2016-08-01 00:00:00
# 2016-08-02 00:00:00
# 2016-08-03 00:00:00
# DatetimeIndex(['2016-07-25', '2016-07-26', '2016-07-27', '2016-07-28',
#                '2016-07-29', '2016-07-30', '2016-07-31', '2016-08-01',
#                '2016-08-02', '2016-08-03'],
#               dtype='datetime64[ns]', name='Date', freq=None)

# %%
os.chdir(r"/home/braincourt.de/mnelz/Documents/Python/Cryptocurrency")
agent_file = r"Reinforcement_Learning_for_Stock_Prediction-master/agent/agent.py"
functions_file = r"Reinforcement_Learning_for_Stock_Prediction-master/functions.py"
exec(open(agent_file).read())
exec(open(functions_file).read())

# %%
        
#from agent.agent import Agent
#from functions import *

import sys
#
#if len(sys.argv) != 4:
#    print("Usage: python train.py [stock] [window] [episodes]")
#    exit()
#
window_size = 10
episode_count = 500
add_mean = True
#
if add_mean:
    agent = Agent(window_size + 1)
else: 
    agent = Agent(window_size)
data = data_full['BTC'][1000:]
#print(data)
l = len(data) - 1
batch_size = 32
#getState()
budget_start = 20000
budget_start = np.max(data) * len(data)

profits = []
for e in range(episode_count + 1):
    
    states_sell = []
    states_buy = []
    
    budget = budget_start
    print("Episode " + str(e) + "/" + str(episode_count))
    state = getState(data, 0, window_size + 1)

    if add_mean:
        a = [i for j in state for i in j]
        a.append(0)
        state = np.array([a])
    total_profit = 0
    agent.inventory = []
    
    for t in range(l):
        if t == 0:
            agent.inventory.append(data[t])
            budget -= data[t]
            states_buy.append(t)
            # wenn gekauft, dann ist Reward Preisunterschied zum vorherigen Preis
            reward = mean_price - data[t]
            print("Buy: " + formatPrice(data[t]))
        else:
            #print(t)
            action = agent.act(state)

            # sit
            next_state = getState(data, t + 1, window_size + 1)
            #reward = - np.min(data)#/10
            reward = 0

            if t != 0 and t > int(window_size/2):
                mean_price = np.mean(data[(t - int(window_size/2)):(t-1)])  
            elif t > 1:
                mean_price = np.mean(data[0:(t-1)]) 
            else:
                mean_price = data[0]

            if action == 1 and np.sum(agent.inventory) + data[t] <= budget: # buy
                agent.inventory.append(data[t])
                budget -= data[t]
                states_buy.append(t)
                # wenn gekauft, dann ist Reward Preisunterschied zum vorherigen Preis
                #reward = mean_price - data[t]
                print("Buy: " + formatPrice(data[t]))

            elif action == 2 and len(agent.inventory) > 0:# and data[t] > mean_price: # sell
                bought_price = agent.inventory.pop(0)
                reward = max(data[t] - bought_price, 0)
                #reward = data[t] - bought_price
                total_profit += data[t] - bought_price
                budget += data[t] 
                states_sell.append(t)
                print("Sell: " + formatPrice(data[t]) + " | Profit: " + formatPrice(data[t] - bought_price))

                #agent.inventory.append(data[t])
                #print("Sell: " + formatPrice(data[t]) + " | Profit: " + str(round(np.sum(agent.inventory),2)))

            # Verluste stärker bestrafen(penalty_factor > 1) bzw. geringer zu bestrafen (1 > penalty_factor > 0):
            # dank relu ohne effekt
            penalty_factor = 1
            if reward < 0:
                reward = reward * penalty_factor

            done = True if t == l - 1 else False
            if add_mean:
                a = [i for j in next_state for i in j]
                a.append(mean_price/1000)
                next_state = np.array([a])
            agent.memory.append((state, action, reward, next_state, done))
            state = next_state

            if done:
                print("--------------------------------")
                print("Total Profit: " + formatPrice(total_profit))
                print("Final Budget: " + formatPrice(budget))
                print("--------------------------------")
                profits.append(total_profit)

            if len(agent.memory) > batch_size:
                #print('Learn!')
                agent.expReplay(batch_size)

    if e % 1 == 0:
        try: 
            os.mkdir('models')
        except:
            pass
        agent.model.save("models/model_ep" + str(e))
    
    try: 
        os.mkdir('models/plots')
    except:
        pass
    
    
    figure = "models/plots/model_ep{}.png".format(str(e))
    plt.figure(figsize = (20, 10))
    plt.plot(data, label = 'BTC/USDT', c = 'black')
    plt.text(np.min(data.index),np.max(data),'Profit:{}'.format(round(total_profit,0)))
    plt.title('When to buy and sell Bitcoins')
    plt.plot(data, 'o', label = 'predict buy', markevery = states_buy, c = 'g')
    plt.plot(data, 'o', label = 'predict sell', markevery = states_sell, c = 'r')
    plt.legend()
    plt.show()
    plt.savefig(figure)
    
    if (e + 1) % 5 == 0:
        pd.Series(profits).plot()
        plt.show()
# Out:
# Episode 0/50
# Buy: $5506.78
# Sell: $5523.84 | Profit: $17.05
# Buy: $5540.89
# Buy: $5477.19
# Buy: $5152.54
# Buy: $5150.28
# Buy: $5149.15
# Buy: $5148.02
# Buy: $5218.46
# Sell: $5691.58 | Profit: $150.70
# Sell: $5770.44 | Profit: $293.25
# Sell: $5809.86 | Profit: $657.33
# Buy: $5844.36
# Sell: $5849.29 | Profit: $699.01
# Buy: $6045.30
# Buy: $7646.12
# Buy: $7990.38
# Sell: $7983.74 | Profit: $2834.59
# Buy: $7196.20
# Buy: $7549.31
# Buy: $7950.56
# Sell: $7832.24 | Profit: $2684.22
# /opt/anaconda/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: RuntimeWarning:
#
# invalid value encountered in double_scalars
# Sell: $8350.83 | Profit: $3132.37
# Sell: $8519.95 | Profit: $2675.59
# Sell: $8689.06 | Profit: $2643.77
# Buy: $8624.94
# Buy: $8559.94
# Buy: $8333.64
# Sell: $8409.21 | Profit: $763.10
# Buy: $8434.40
# Buy: $7766.79
# Sell: $7698.83 | Profit: -$291.55
# Buy: $7821.54
# Buy: $7841.99
# Sell: $8066.25 | Profit: $870.06
# Sell: $8188.03 | Profit: $638.72
# Sell: $8426.45 | Profit: $475.89
# Buy: $8840.48
# Buy: $9254.52
# Buy: $9120.96
# Sell: $9154.57 | Profit: $529.62
# Sell: $9392.79 | Profit: $832.85
# Sell: $9828.26 | Profit: $1494.63
# Buy: $10589.50
# Buy: $11335.61
# Sell: $12704.02 | Profit: $4269.61
# Sell: $11668.68 | Profit: $3901.89
# Buy: $10848.72
# Sell: $10575.40 | Profit: $2753.86
# Sell: $10225.36 | Profit: $2383.37
# Buy: $11361.91
# Buy: $11110.50
# Sell: $11522.77 | Profit: $2682.28
# Sell: $11728.90 | Profit: $2474.38
# Buy: $11935.03
# Sell: $12489.61 | Profit: $3368.65
# Sell: $10402.83 | Profit: -$186.67
# Sell: $9998.75 | Profit: -$1336.87
# Sell: $9549.27 | Profit: -$1299.45
# Sell: $10095.67 | Profit: -$1266.23
# Buy: $10442.64
# Buy: $10405.83
# Sell: $10025.33 | Profit: -$1085.17
# Buy: $9704.71
# Sell: $10010.55 | Profit: -$1924.48
# Sell: $9593.90 | Profit: -$848.74
# Sell: $10140.38 | Profit: -$265.46
# Sell: $11069.65 | Profit: $1364.94
# Buy: $11761.57
# Buy: $11821.57
# Buy: $11601.55
# Buy: $11491.55
# Sell: $11381.54 | Profit: -$380.03
# Buy: $9957.77
# Buy: $10675.22
# Sell: $10195.03 | Profit: -$1626.54
# Sell: $10178.93 | Profit: -$1422.62
# Buy: $10162.84
# Sell: $9494.60 | Profit: -$1996.95
# Buy: $10562.12
# Buy: $10559.12
# Sell: $10372.33 | Profit: $414.56
# Sell: $10268.46 | Profit: -$406.76
# Sell: $10225.46 | Profit: $62.62
# Sell: $10184.48 | Profit: -$377.65
# Buy: $9909.28
# Sell: $8831.98 | Profit: -$1727.14
# Buy: $8112.14
# Sell: $8040.56 | Profit: -$1868.72
# Buy: $8054.75
# Sell: $8135.58 | Profit: $23.44
# Buy: $8173.63
# Buy: $8192.66
# Sell: $8209.31 | Profit: $154.56
# Sell: $8211.68 | Profit: $38.05
# Sell: $8378.52 | Profit: $185.87
# Buy: $8079.71
# Sell: $8152.23 | Profit: $72.52
# Buy: $8864.14
# --------------------------------
# Total Profit: $27232.29
# Final Budget: $2444835.08
# --------------------------------
# Episode 1/50
# Buy: $5506.78
# Sell: $5149.15 | Profit: -$357.63
# Buy: $5148.02
# Buy: $5218.46
# Sell: $5829.58 | Profit: $681.55
# Sell: $5839.43 | Profit: $620.97
# Buy: $7721.84
# Sell: $8624.94 | Profit: $903.10
# Buy: $8559.94
# Buy: $7800.38
# Sell: $7876.96 | Profit: -$682.98
# Sell: $9047.50 | Profit: $1247.12
# Buy: $11555.50
# Buy: $10691.00
# Sell: $10402.83 | Profit: -$1152.66
# Buy: $9549.27
# Sell: $10442.64 | Profit: -$248.36
# Sell: $9704.71 | Profit: $155.44
# Buy: $10010.55
# Sell: $11361.76 | Profit: $1351.20
# Buy: $9957.77
# Sell: $10001.42 | Profit: $43.65
# Buy: $10291.60
# Sell: $10559.12 | Profit: $267.52
# Buy: $10059.05
# Buy: $8054.75
# Sell: $8202.17 | Profit: -$1856.88
# Sell: $8555.40 | Profit: $500.65
# --------------------------------
# Total Profit: $1472.69
# Final Budget: $2427939.63
# --------------------------------
# Episode 2/50
# Buy: $5506.78
# Buy: $5523.84
# Sell: $5293.84 | Profit: -$212.95
# Buy: $5152.54
# Sell: $5844.36 | Profit: $320.53
# Sell: $6970.72 | Profit: $1818.19
# Buy: $8188.03
# Sell: $8426.45 | Profit: $238.41
# Buy: $10227.22
# Buy: $10164.75
# Sell: $8206.93 | Profit: -$2020.29
# Sell: $8243.28 | Profit: -$1921.47
# Buy: $8049.55
# --------------------------------
# Total Profit: -$1777.58
# Final Budget: $2416639.80
# --------------------------------
# Episode 3/50
# Buy: $5506.78
# Sell: $5218.46 | Profit: -$288.32
# Buy: $9998.75
# --------------------------------
# Total Profit: -$288.32
# Final Budget: $2416179.86
# --------------------------------
# Episode 4/50
# Buy: $5506.78
# Sell: $7800.38 | Profit: $2293.59
# --------------------------------
# Total Profit: $2293.59
# Final Budget: $2428760.53
# --------------------------------
# Episode 5/50
# Buy: $5506.78
# /opt/anaconda/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: RuntimeWarning:
#
# invalid value encountered in double_scalars
# Buy: $11761.57
# Buy: $11821.57
# Sell: $8135.58 | Profit: $2628.79
# --------------------------------
# Total Profit: $2628.79
# Final Budget: $2405512.59
# --------------------------------
# Episode 6/50
# Buy: $5506.78
# Sell: $9549.27 | Profit: $4042.49
# --------------------------------
# Total Profit: $4042.49
# Final Budget: $2430509.42
# --------------------------------
# Episode 7/50
# Buy: $5506.78
# --------------------------------
# Total Profit: $0.00
# Final Budget: $2420960.15
# --------------------------------
# Episode 8/50
# Buy: $5506.78
# Buy: $5477.19
# Sell: $11506.25 | Profit: $5999.47
# Sell: $11783.97 | Profit: $6306.78
# --------------------------------
# Total Profit: $12306.24
# Final Budget: $2438773.18
# --------------------------------
# Episode 9/50
# Buy: $5506.78
# --------------------------------
# Total Profit: $0.00
# Final Budget: $2420960.15
# --------------------------------
# Episode 10/50
# Buy: $5506.78
# /opt/anaconda/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: RuntimeWarning:
#
# invalid value encountered in double_scalars
# Buy: $5218.46
# --------------------------------
# Total Profit: $0.00
# Final Budget: $2415741.69
# --------------------------------
# Episode 11/50
# Buy: $5506.78
# Buy: $8333.64
# --------------------------------
# Total Profit: $0.00
# Final Budget: $2412626.51
# --------------------------------
# Episode 12/50
# Buy: $5506.78
# Sell: $9994.44 | Profit: $4487.65
# --------------------------------
# Total Profit: $4487.65
# Final Budget: $2430954.59
# --------------------------------
# Episode 13/50
# Buy: $5506.78
# Buy: $8384.02
# Buy: $11122.04
# Sell: $9186.12 | Profit: $3679.33
# --------------------------------
# Total Profit: $3679.33
# Final Budget: $2410640.20
# --------------------------------
# Episode 14/50
# Buy: $5506.78
# Buy: $8243.28
# Buy: $8220.19
# --------------------------------
# Total Profit: $0.00
# Final Budget: $2404496.68
# --------------------------------
# Episode 15/50
# Buy: $5506.78
# /opt/anaconda/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: RuntimeWarning:
#
# invalid value encountered in double_scalars
# --------------------------------
# Total Profit: $0.00
# Final Budget: $2420960.15
# --------------------------------
# Episode 16/50
# Buy: $5506.78
# Buy: $5523.84
# Sell: $5148.02 | Profit: -$358.76
# Buy: $11335.61
# --------------------------------
# Total Profit: -$358.76
# Final Budget: $2409248.72
# --------------------------------
# Episode 17/50
# Buy: $5506.78
# Sell: $8112.14 | Profit: $2605.36
# --------------------------------
# Total Profit: $2605.36
# Final Budget: $2429072.29
# --------------------------------
# Episode 18/50
# Buy: $5506.78
# --------------------------------
# Total Profit: $0.00
# Final Budget: $2420960.15
# --------------------------------
# Episode 19/50
# Buy: $5506.78
# Sell: $8012.59 | Profit: $2505.81
# --------------------------------
# Total Profit: $2505.81
# Final Budget: $2428972.74
# --------------------------------
# Episode 20/50
# Buy: $5506.78
# /opt/anaconda/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: RuntimeWarning:
#
# invalid value encountered in double_scalars
# Sell: $7646.12 | Profit: $2139.33
# --------------------------------
# Total Profit: $2139.33
# Final Budget: $2428606.27
# --------------------------------
# Episode 21/50
# Buy: $5506.78
# Buy: $8559.94
# --------------------------------
# Total Profit: $0.00
# Final Budget: $2412400.21
# --------------------------------
# Episode 22/50
# Buy: $5506.78
# Buy: $11046.86
# Sell: $10675.22 | Profit: $5168.43
# Sell: $9986.05 | Profit: -$1060.81
# --------------------------------
# Total Profit: $4107.63
# Final Budget: $2430574.56
# --------------------------------
# Episode 23/50
# Buy: $5506.78
# --------------------------------
# Total Profit: $0.00
# Final Budget: $2420960.15
# --------------------------------
# Episode 24/50
# Buy: $5506.78
# Buy: $8624.94
# Sell: $11522.77 | Profit: $6015.98
# Buy: $9986.05
# --------------------------------
# Total Profit: $6015.98
# Final Budget: $2413871.92
# --------------------------------
# Episode 25/50
# Buy: $5506.78
# /opt/anaconda/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: RuntimeWarning:
#
# invalid value encountered in double_scalars
# --------------------------------
# Total Profit: $0.00
# Final Budget: $2420960.15
# --------------------------------
# Episode 26/50
# Buy: $5506.78
# Sell: $8689.06 | Profit: $3182.28
# --------------------------------
# Total Profit: $3182.28
# Final Budget: $2429649.21
# --------------------------------
# Episode 27/50
# Buy: $5506.78
# --------------------------------
# Total Profit: $0.00
# Final Budget: $2420960.15
# --------------------------------
# Episode 28/50
# Buy: $5506.78
# Sell: $8555.40 | Profit: $3048.62
# --------------------------------
# Total Profit: $3048.62
# Final Budget: $2429515.55
# --------------------------------
# Episode 29/50
# Buy: $5506.78
# Buy: $11668.68
# --------------------------------
# Total Profit: $0.00
# Final Budget: $2409291.47
# --------------------------------
# Episode 30/50
# Buy: $5506.78
# /opt/anaconda/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: RuntimeWarning:
#
# invalid value encountered in double_scalars
# Buy: $5691.58
# Sell: $8624.94 | Profit: $3118.16
# Buy: $9549.27
# Buy: $10742.53
# Buy: $10178.93
# --------------------------------
# Total Profit: $3118.16
# Final Budget: $2393422.78
# --------------------------------
# Episode 31/50
# Buy: $5506.78
# --------------------------------
# Total Profit: $0.00
# Final Budget: $2420960.15
# --------------------------------
# Episode 32/50
# Buy: $5506.78
# --------------------------------
# Total Profit: $0.00
# Final Budget: $2420960.15
# --------------------------------
# Episode 33/50
# Buy: $5506.78
# Buy: $10442.64
# --------------------------------
# Total Profit: $0.00
# Final Budget: $2410517.51
# --------------------------------
# Episode 34/50
# Buy: $5506.78
# --------------------------------
# Total Profit: $0.00
# Final Budget: $2420960.15
# --------------------------------
# Episode 35/50
# Buy: $5506.78
# /opt/anaconda/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: RuntimeWarning:
#
# invalid value encountered in double_scalars
# --------------------------------
# Total Profit: $0.00
# Final Budget: $2420960.15
# --------------------------------
# Episode 36/50
# Buy: $5506.78
# --------------------------------
# Total Profit: $0.00
# Final Budget: $2420960.15
# --------------------------------
# Episode 37/50
# Buy: $5506.78
# Buy: $8062.63
# Buy: $10559.12
# --------------------------------
# Total Profit: $0.00
# Final Budget: $2402338.40
# --------------------------------
# Episode 38/50
# Buy: $5506.78
# Sell: $7698.83 | Profit: $2192.05
# --------------------------------
# Total Profit: $2192.05
# Final Budget: $2428658.98
# --------------------------------
# Episode 39/50
# Buy: $5506.78
# Buy: $8409.21
# --------------------------------
# Total Profit: $0.00
# Final Budget: $2412550.94
# --------------------------------
# Episode 40/50
# Buy: $5506.78
# /opt/anaconda/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: RuntimeWarning:
#
# invalid value encountered in double_scalars
# Buy: $9998.75
# --------------------------------
# Total Profit: $0.00
# Final Budget: $2410961.40
# --------------------------------
# Episode 41/50
# Buy: $5506.78
# Sell: $8555.40 | Profit: $3048.62
# --------------------------------
# Total Profit: $3048.62
# Final Budget: $2429515.55
# --------------------------------
# Episode 42/50
# Buy: $5506.78
# --------------------------------
# Total Profit: $0.00
# Final Budget: $2420960.15
# --------------------------------
# Episode 43/50
# Buy: $5506.78
# Buy: $5148.02
# Buy: $12487.70
# --------------------------------
# Total Profit: $0.00
# Final Budget: $2403324.43
# --------------------------------
# Episode 44/50
# Buy: $5506.78
# Sell: $10559.12 | Profit: $5052.33
# --------------------------------
# Total Profit: $5052.33
# Final Budget: $2431519.27
# --------------------------------
# Episode 45/50
# Buy: $5506.78
# /opt/anaconda/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: RuntimeWarning:
#
# invalid value encountered in double_scalars
# Sell: $10675.22 | Profit: $5168.43
# --------------------------------
# Total Profit: $5168.43
# Final Budget: $2431635.37
# --------------------------------
# Episode 46/50
# Buy: $5506.78
# Sell: $5152.54 | Profit: -$354.25
# Buy: $10059.05
# Sell: $8050.02 | Profit: -$2009.03
# --------------------------------
# Total Profit: -$2363.28
# Final Budget: $2424103.65
# --------------------------------
# Episode 47/50
# Buy: $5506.78
# Sell: $10559.12 | Profit: $5052.33
# --------------------------------
# Total Profit: $5052.33
# Final Budget: $2431519.27
# --------------------------------
# Episode 48/50
# Buy: $5506.78
# --------------------------------
# Total Profit: $0.00
# Final Budget: $2420960.15
# --------------------------------
# Episode 49/50
# Buy: $5506.78
# Buy: $7698.83
# --------------------------------
# Total Profit: $0.00
# Final Budget: $2413261.32
# --------------------------------
# Episode 50/50
# Buy: $5506.78
# /opt/anaconda/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: RuntimeWarning:
#
# invalid value encountered in double_scalars
# --------------------------------
# Total Profit: $0.00
# Final Budget: $2420960.15
# --------------------------------

# %%
#pd.Series(profits).plot()
#pd.Series(profits).mean()
print(next_state.tolist())
a = [i for j in next_state for i in j]
print(a)
a.append(3.0)
print(np.array([a]))
#next_state = np.append(next_state,3)
#print(next_state)
# Out:
# [[0.5142099090547886, 0.4765190720649508, 0.6307838265297363, 0.5665503842758963, 0.5665503842758908, 0.4772863681242146, 0.4507425995978283, 0.3667799331778025, 0.5702962372097702, 0.4772043230690894]]
# [0.5142099090547886, 0.4765190720649508, 0.6307838265297363, 0.5665503842758963, 0.5665503842758908, 0.4772863681242146, 0.4507425995978283, 0.3667799331778025, 0.5702962372097702, 0.4772043230690894]
# [[0.51420991 0.47651907 0.63078383 0.56655038 0.56655038 0.47728637
#   0.4507426  0.36677993 0.57029624 0.47720432 3.        ]]

# %%
import keras
from keras.models import load_model

#from agent.agent import Agent
#from functions import *
import sys

#stock_name, 
model_name = 'model_ep0'
model = load_model("models/" + model_name)
window_size = model.layers[0].input.shape.as_list()[1]

agent = Agent(window_size, True, model_name)
data = data
l = len(data) - 1
batch_size = 32

budget_start = 20000

state = getState(data, 0, window_size + 1)
total_profit = 0
agent.inventory = []

states_sell = []
states_buy = []

for t in range(l):
    action = agent.act(state)

    # sit
    next_state = getState(data, t + 1, window_size + 1)
    reward = 0
    
    mean_price = np.mean(data[0:t]) if t != 0 else data[0]
        
    if action == 1 and np.sum(agent.inventory) + data[t] <= budget: # buy
        agent.inventory.append(data[t])
        budget -= data[t]
        states_buy.append(t)
        print("Buy: " + formatPrice(data[t]))

    elif action == 2 and len(agent.inventory) > 0 and data[t] > mean_price: # sell
        bought_price = agent.inventory.pop(0)
        reward = max(data[t] - bought_price, 0)
        total_profit += data[t] - bought_price
        budget += data[t] 
        states_sell.append(t)
        print("Sell: " + formatPrice(data[t]) + " | Profit: " + formatPrice(data[t] - bought_price))
        
    done = True if t == l - 1 else False
    agent.memory.append((state, action, reward, next_state, done))
    state = next_state

    if done:
        print("--------------------------------")
        print(" Total Profit: " + formatPrice(total_profit))
        print("--------------------------------")

if len(agent.memory) > batch_size:
    agent.expReplay(batch_size)        

#figure = "models/plots/model_ep{}.png".format(str(e))
plt.figure(figsize = (20, 10))
plt.plot(data, label = 'BTC/USDT', c = 'black')
plt.text(np.min(data.index),np.max(data),'Profit:{}'.format(round(total_profit,0)))
plt.title('When to buy and sell Bitcoins')
plt.plot(data, 'o', label = 'predict buy', markevery = states_buy, c = 'g')
plt.plot(data, 'o', label = 'predict sell', markevery = states_sell, c = 'r')
plt.legend()
#plt.savefig(figure)
# Out:
# --------------------------------
#  Total Profit: $0.00
# --------------------------------

# %%
a = [1,2,3,4,5,6,7,8,9]
s = 6
a[:s]
# Out:
# [1, 2, 3, 4, 5, 6]
